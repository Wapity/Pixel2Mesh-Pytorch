# %%
f = open('trainer_res.txt','r')
out = f.readlines()

# %%
out
# Out:
# ['data/training_data/ShapeNetP2M/04256520/1a4a8592046253ab5ff61a3a2a0e2484/rendering/00.dat\n',
#  'data/training_data/ShapeNetP2M/04256520/1a4a8592046253ab5ff61a3a2a0e2484/rendering/01.dat\n',
#  'data/training_data/ShapeNetP2M/04256520/1a4a8592046253ab5ff61a3a2a0e2484/rendering/02.dat\n',
#  'data/training_data/ShapeNetP2M/04256520/1a4a8592046253ab5ff61a3a2a0e2484/rendering/03.dat\n',
#  'data/training_data/ShapeNetP2M/04256520/1a4a8592046253ab5ff61a3a2a0e2484/rendering/04.dat\n',
#  'data/training_data/ShapeNetP2M/04256520/1a04dcce7027357ab540cc4083acfa57/rendering/00.dat\n',
#  'data/training_data/ShapeNetP2M/04256520/1a04dcce7027357ab540cc4083acfa57/rendering/01.dat\n',
#  'data/training_data/ShapeNetP2M/04256520/1a04dcce7027357ab540cc4083acfa57/rendering/02.dat\n',
#  'data/training_data/ShapeNetP2M/04256520/1a04dcce7027357ab540cc4083acfa57/rendering/03.dat\n',
#  'data/training_data/ShapeNetP2M/04256520/1a04dcce7027357ab540cc4083acfa57/rendering/04.dat\n',
# ...

# %%
liste=[]
for i in range(len(out)):
        liste.append(out[i][:19]+'__MACOSX/Test/'+ out[i][40:])
liste
# Out:
# ['data/training_data/__MACOSX/Test/1a4a8592046253ab5ff61a3a2a0e2484/rendering/00.dat\n',
#  'data/training_data/__MACOSX/Test/1a4a8592046253ab5ff61a3a2a0e2484/rendering/01.dat\n',
#  'data/training_data/__MACOSX/Test/1a4a8592046253ab5ff61a3a2a0e2484/rendering/02.dat\n',
#  'data/training_data/__MACOSX/Test/1a4a8592046253ab5ff61a3a2a0e2484/rendering/03.dat\n',
#  'data/training_data/__MACOSX/Test/1a4a8592046253ab5ff61a3a2a0e2484/rendering/04.dat\n',
#  'data/training_data/__MACOSX/Test/1a04dcce7027357ab540cc4083acfa57/rendering/00.dat\n',
#  'data/training_data/__MACOSX/Test/1a04dcce7027357ab540cc4083acfa57/rendering/01.dat\n',
#  'data/training_data/__MACOSX/Test/1a04dcce7027357ab540cc4083acfa57/rendering/02.dat\n',
#  'data/training_data/__MACOSX/Test/1a04dcce7027357ab540cc4083acfa57/rendering/03.dat\n',
#  'data/training_data/__MACOSX/Test/1a04dcce7027357ab540cc4083acfa57/rendering/04.dat\n',
# ...

# %%
with open('f1_list.txt','w') as stereo :
    stereo.writelines(liste)
