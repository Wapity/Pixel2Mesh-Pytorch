# %%
f = open('trainer_res.txt','r')
out = f.readlines()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-e2f0982cf49d> in <module>
# ----> 1 f = open('trainer_res.txt','r')
#       2 out = f.readlines()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'trainer_res.txt'

# %%
out
# Out:
# ['data/training_data/ShapeNetP2M/04256520/1a4a8592046253ab5ff61a3a2a0e2484/rendering/00.dat,data/training_data/ShapeNetP2M/04256520/1a4a8592046253ab5ff61a3a2a0e2484/rendering/00.png,data/training_data/ShapeNetP2M/04256520/1a4a8592046253ab5ff61a3a2a0e2484/rendering/03.png\n',
#  'data/training_data/ShapeNetP2M/04256520/1a04dcce7027357ab540cc4083acfa57/rendering/00.dat,data/training_data/ShapeNetP2M/04256520/1a04dcce7027357ab540cc4083acfa57/rendering/00.png,data/training_data/ShapeNetP2M/04256520/1a04dcce7027357ab540cc4083acfa57/rendering/03.png\n',
#  'data/training_data/ShapeNetP2M/04256520/1a9d0480b74d782698f5bccb3529a48d/rendering/00.dat,data/training_data/ShapeNetP2M/04256520/1a9d0480b74d782698f5bccb3529a48d/rendering/00.png,data/training_data/ShapeNetP2M/04256520/1a9d0480b74d782698f5bccb3529a48d/rendering/03.png\n',
# ...

# %%
liste=[]
for i in range(len(out)):
    for j in range(1,5,1):
        liste.append(out[i][:-6]+str(j)+'.png\n') 
liste
# Out:
# ['data/training_data/ShapeNetP2M/04256520/1a4a8592046253ab5ff61a3a2a0e2484/rendering/00.dat,data/training_data/ShapeNetP2M/04256520/1a4a8592046253ab5ff61a3a2a0e2484/rendering/00.png,data/training_data/ShapeNetP2M/04256520/1a4a8592046253ab5ff61a3a2a0e2484/rendering/01.png\n',
#  'data/training_data/ShapeNetP2M/04256520/1a4a8592046253ab5ff61a3a2a0e2484/rendering/00.dat,data/training_data/ShapeNetP2M/04256520/1a4a8592046253ab5ff61a3a2a0e2484/rendering/00.png,data/training_data/ShapeNetP2M/04256520/1a4a8592046253ab5ff61a3a2a0e2484/rendering/02.png\n',
#  'data/training_data/ShapeNetP2M/04256520/1a4a8592046253ab5ff61a3a2a0e2484/rendering/00.dat,data/training_data/ShapeNetP2M/04256520/1a4a8592046253ab5ff61a3a2a0e2484/rendering/00.png,data/training_data/ShapeNetP2M/04256520/1a4a8592046253ab5ff61a3a2a0e2484/rendering/03.png\n',
# ...

# %%
with open('list_stereo_full.txt','w') as stereo :
    stereo.writelines(liste)
